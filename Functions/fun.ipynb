# %%
## Syntax
def function_name(parameter):
    print(parameter)
    return "2"

print(function_name("Priyanka"))
# Out:
# Priyanka
# 2

# %%
## Default Parameters

def greet(name):
    print(f"Hello {name} Welcome To the paradise")

greet("Krish")
# Out:
# Hello Krish Welcome To the paradise

# %%
### Variable Length Arguments
## Positional And Keywords arguments

## Positional
def print_numbers(*args):
    for num in args:
        print(num)

print_numbers(1,2,3,4,5,6,"krish")

## Keywords
def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")
print_details(name="krish",age=32,count="2")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# krish
# name:krish
# age:32
# count:2

# %%
#mix 

def print_details(*args,**kwargs):
    for val in args:
        print(f" Positional arument :{val}")
    
    for key,value in kwargs.items():
        print(f"{key}:{value}")

print_details(1,2,3,4,"Krish",name="Krish",age="32",country="India")
# Out:
#  Positional arument :1
#  Positional arument :2
#  Positional arument :3
#  Positional arument :4
#  Positional arument :Krish
# name:Krish
# age:32
# country:India

# %% [markdown]
# #### Example 1: Temperature Conversion

# %%
def convert_temperature(temp,unit):
    """This function converts temperature between Celsius and Fahrenheit"""
    if unit=='C':
        return temp * 9/5 + 32  ## Celsius To Fahrenheit
    elif unit=="F":
        return (temp-32)*5/9 ## Fahrenheit to celsius
    else:
        return None

print(convert_temperature(25,'C'))
print(convert_temperature(77,'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# ##### Example 2: A Function To Read A File and count the frequency of each word

# %%
def count_word_frequency(file_path):
    word_count={}
    with open(file_path,'r') as file:
        for line in file:
            words=line.split()
            for word in words:
                word=word.lower().strip('.,!?;:"\'')
                word_count[word]=word_count.get(word,0)+1
    
    return word_count

filepath='sample.txt'
word_frequency=count_word_frequency(filepath)
print(word_frequency)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 13
#      10     return word_count
#      12 filepath='sample.txt'
# ---> 13 word_frequency=count_word_frequency(filepath)
#      14 print(word_frequency)
#
# Cell In[16], line 3, in count_word_frequency(file_path)
#       1 def count_word_frequency(file_path):
#       2     word_count={}
# ----> 3     with open(file_path,'r') as file:
#       4         for line in file:
#       5             words=line.split()
#
# File c:\Users\pgarg\OneDrive\Documents\vscode\AI-ML\Functions\venv\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
# ...
